# %%
import yaml
import os
import shutil
from datetime import datetime
from openpyxl import load_workbook, Workbook
import h5py

# %matplotlib inline
#%matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2

from yaml_creator import *
root_dir = "\\\\toucan-all.scicore.unibas.ch\\donafl00-calcium$\\Users\\Sergej\\Steffen_Experiments" 
#root_dir = r"Y:\Users\Sergej\Steffen_Experiments"  
#root_dir = "/scicore/projects/donafl00-calcium/Users/Sergej/Steffen_Experiments"
root_animal_yaml_name = "animal_summary.yaml"
fname = os.path.join("Intrinsic_CA3_database-September_7,_10_08_AM.xlsx")
fpath = os.path.join(root_dir, fname)
# Out:
# Autosaving every 180 seconds

# %%
animals_spreadsheed = get_animal_dict_from_spreadsheet(fpath)
# Out:
# Warning cohort_year if defined by dob year.
# Warning dob year 2020 is changed to 2021.

# %%
animals_yaml = get_animals_from_yaml(root_dir)

# %%
animals = add_session_animal_folders(animals_yaml, animals_spreadsheed, directory=root_dir)

# %%
for animal_id, animal in animals.items():
    try:
        print(animal["UseMUnits"])
    except:
        pass
# Out:
# [['DON-006085_20210521_002P-F_S1-ACQ.mesc', [0, 1]]]
# [['DON-009191_20220217_002P-F_S1-S2.mesc', [0, 1, 2]], ['DON-009191_20220218_002P-F_S1-S2.mesc', [0, 1, 2]], ['DON-009191_20220219_002P-F_S1-S2.mesc', [0, 1, 2]], ['DON-009191_20220227_002P-F_S2-S3.mesc', [0, 1, 2]], ['DON-009191_20220305_002P-F_S4.mesc', [0, 1, 2, 6]], ['DON-009191_20220216_002P-F_S1-S2.mesc', [0, 2, 5]]]
# [['DON-009192_20220215_002P-F_S1-S2.mesc', [0, 1, 5, 6]], ['DON-009192_20220216_002P-F_S1-S2.mesc', [0, 1, 2]], ['DON-009192_20220219_002P-F_S1-S2.mesc', [0, 1, 2]], ['DON-009192_20220302_002P-F_S4-S5.mesc', [2, 3, 4]], ['DON-009192_20220304_002P-F_S3.mesc', [0, 1, 2]], ['DON-009192_20220305_002P-F_S4.mesc', [0, 2]]]
# [['DON-010473_20220516_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010473_20220517_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010473_20220518_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010473_20220531_002P-F_S1-ACQ.mesc', [0, 1]]]
# [['DON-010477_20220516_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010477_20220517_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010477_20220518_002P-F_S1_S2-ACQ.mesc', [0, 1]], ['DON-010477_20220530_002P-F_S1-ACQ.mesc', [0, 1]], ['DON-010477_20220531_002P-F_S1-ACQ.mesc', [0, 1]]]
# [['DON-014837_20230227_002P-F_S1-ACQ.mesc', [0, 1]]]
# [['DON-014838_20230227_002P-F_S1-ACQ.mesc', [0, 1]], ['DON-014838_20230303_002P-F_S1-ACQ.mesc', [0, 1]]]
# [['DON-014840_20230304_002P-F_S1-S2-ACQ.mesc', [0, 1, 2]], ['DON-014840_20230312_002P-F_S1ACQ.mesc', [0, 1]]]

# %%
# load spreadsheet information
animals_spreadsheed = get_animal_dict_from_spreadsheet(fpath)
# load animal yaml files
animals_yaml = get_animals_from_yaml(root_dir)
# get animals based on folder structure
move_mesc_to_session_folder(directory=root_dir)
animals = add_session_animal_folders(animals_spreadsheed, directory=root_dir)
for animal_id, animal in animals.items():
    print(animal)

# %%
# save yaml files in folders and root directory
add_yaml_to_folders(animals, directory=root_dir)
with open(os.path.join(root_dir, root_animal_yaml_name), 'w') as file:
    yaml.dump(animals, file)
